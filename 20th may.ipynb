# %%
import numpy as np
arr = np.array([1,2,3])
print(arr)
# Out:
# [1 2 3]

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr.shape
# Out:
# (3,)

# %%
arr2 = np.array([[1,2],[3,4]])
print(arr2)
# Out:
# [[1 2]
#  [3 4]]

# %%
arr.shape
# Out:
# (3,)

# %%
threeD_array = np.array([[[1,2],[3,4]],[[5,6],[7,8]]])
print(threeD_array)
print(threeD_array.shape)
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]
# (2, 2, 2)

# %%
py_list = [1,2,3]
print(py_list*2)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
print(py_list+[2])
# Out:
# [1, 2, 3, 2]

# %%
np_array = np.array([1,2,3])
print(np_array*2)
# Out:
# [2 4 6]

# %%
import pandas as pd

# %%
data = {"Name":["Asha","Rahul","Neha"],"Marks":[85,90,78]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Marks
# 0   Asha     85
# 1  Rahul     90
# 2   Neha     78

# %%
data_dict = {
    'Name':['Alice','Bob','Charlie','David','Eva'],
    'Age':[25,np.nan,30,22,28],
    'score':[85,90,95,80,70]
}
df = pd.DataFrame(data_dict)
print(df)
# Out:
#       Name   Age  score
# 0    Alice  25.0     85
# 1      Bob   NaN     90
# 2  Charlie  30.0     95
# 3    David  22.0     80
# 4      Eva  28.0     70

# %%
print("Null values per column:\n",df.isnull().sum())
# Out:
# Null values per column:
#  Name     0
# Age      1
# score    0
# dtype: int64

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp310-cp310-win_amd64.whl (8.2 MB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anjoe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.9.0.post0)
# Collecting pyparsing>=3
#   Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.5.0-cp310-cp310-win_amd64.whl (73 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\anjoe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.2.6)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Requirement already satisfied: pillow>=8 in c:\users\anjoe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\anjoe\appdata\roaming\python\python310\site-packages (from matplotlib) (26.2)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.63.0-cp310-cp310-win_amd64.whl (1.6 MB)
# Requirement already satisfied: six>=1.5 in c:\users\anjoe\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.10.9 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 26.1.1 is available.
# You should consider upgrading via the 'c:\Users\anjoe\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
x = [1,2,3,4,5]
y = [10,14,12,18,20]

plt.plot(x,y,marker='o')
plt.title("Simple Line chart")
plt.xlabel("Time")
plt.ylabel("Distance")
plt.grid(True)
plt.show()

# %%
students = ["A","B","C","D","E"]
marks = [85,70,90,65,95]

plt.bar(students, marks)
plt.title("Students marks")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()

# %%
students = ["A", "B", "C", "D", "E"]
marks = [85, 70, 90, 65, 95]
plt.bar(students, marks, color=["red", "blue", "green", "orange", "purple"])
plt.title("Student Marks")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.show()

# %%
activities = ["Study", "Exercise", "Sleep", "Hobbies"]
hours = [4, 1, 7, 2]
plt.pie(hours,labels=activities,autopct='%1.1f%%')
plt.title("Daily activities")
plt.show()
